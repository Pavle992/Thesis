# %% [markdown]
# # Main Sentiment Calculator

# %%
# -*- coding: utf-8 -*-
from SentimentCalculator import SentimentCalculator
import db_helper as db
import json
import sys

s = SentimentCalculator()

# postID = int(sys.argv[1])

postID = 335758

listOfCom = db.getAllCommentsForPost(postID)
sent = s.calcSummedSentiment(listOfCom)

db.insertSentForPost(postID, sent)
# Out:
# Connected to DB..
# Executin query:  select content from im_commento where idpost = 335758
# Closed DB connection..
# Ohhhh look it's Gaia!! 💄👠
# ################################################
# emojis found: ['💄', '👠']
# text found: Ohhhh look it's Gaia!!
# translated text: Ohhhh look it's Gaia!!
# sentiment for text: 0.0
# sentiment for emojis: 0.41774891774891776
# sentiment combined: 0.41774891774891776
# ################################################
# We love your shoes!! Both of us 😍💄👠
# ################################################
# emojis found: ['😍', '💄', '👠']
# text found: We love your shoes!! Both of us
# translated text: We love your shoes!! Both of us
# sentiment for text: 0.6988
# sentiment for emojis: 0.504478206003603
# sentiment combined: 0.6016391030018016
# ################################################
# how cute she is :) adorable xx
# ################################################
# text found: how cute she is :) adorable xx
# translated text: how cute she is :) adorable xx
# sentiment for text: 0.8481
# sentiment for emojis: 0
# sentiment combined: 0.8481
# ################################################
# Future fashionista💄💄💄💄
# ################################################
# emojis found: ['💄', '💄', '💄', '💄']
# text found: Future fashionista
# translated text: Future fashionista
# sentiment for text: 0.0
# sentiment for emojis: 0.5795454545454545
# sentiment combined: 0.5795454545454545
# ################################################
# Fantastic! Stylish and cute ❤️💋
# ################################################
# emojis found: ['❤', '💋']
# text found: Fantastic! Stylish and cute ️
# translated text: Fantastic! Stylish and cute ️
# sentiment for text: 0.784
# sentiment for emojis: 0.7197737234924773
# sentiment combined: 0.7518868617462386
# ################################################
# Hahaha!! Yes it is 😘😘😘
# ################################################
# emojis found: ['😘', '😘', '😘']
# text found: Hahaha!! Yes it is
# translated text: Hahaha!! Yes it is
# sentiment for text: 0.7835
# sentiment for emojis: 0.8684210526315791
# sentiment combined: 0.8259605263157895
# ################################################
# {'text': 0.5190666666666667, 'emojis': 0.5149945590703385, 'combined': 0.6708134772263671}
# Connected to DB..
# Executin query:   CREATE TABLE IF NOT EXISTS `im_postsentiment` (
#   				`id` int(11) NOT NULL AUTO_INCREMENT,
#   				`idpost` int(11) DEFAULT NULL COMMENT 'post id',
#   				`text_sentiment` FLOAT(11,5),
#   				`emoji_sentiment` FLOAT(11,5),
#   				`combined_sentiment` FLOAT(11,5),
#   				PRIMARY KEY (`id`)
# 				) ENGINE=InnoDB AUTO_INCREMENT=0 DEFAULT CHARSET=utf8mb4;
# Executin query:   insert into im_postsentiment (idpost, text_sentiment, emoji_sentiment, combined_sentiment)
# 				values (335758, 0.5190666666666667, 0.5149945590703385, 0.6708134772263671);
# Closed DB connection..
# C:\Users\Pavle\Miniconda3\envs\thesis\lib\site-packages\pymysql\cursors.py:166: Warning: (1050, "Table 'im_postsentiment' already exists")
#   result = self._query(query)

# %% [markdown]
# # Main Batch Sentiment Claculator

# %%
# -*- coding: utf-8 -*-
from SentimentCalculator import SentimentCalculator
import db_helper as db

conn = db.db_connect()

query = "select distinct idpost from im_commento"
cur = db.doQuery(conn, query)

results = cur.fetchall()

s = SentimentCalculator()

for r in results[:10]:
	listOfCom = db.getAllCommentsForPost(r[0])
	sent = s.calcSummedSentiment(listOfCom)
	db.insertSentForPost(r[0], sent)
# Out:
# Connected to DB..
# Executin query:  select distinct idpost from im_commento
# Connected to DB..
# Executin query:  select content from im_commento where idpost = 79726
# Closed DB connection..
# Se venite a casa mia ve regalo il GameBoy con la cassetta di Super Mario e fate prima.
# ################################################
# text found: Se venite a casa mia ve regalo il GameBoy con la cassetta di Super Mario e fate prima.
# translated text: If you come to my house, give me the GameBoy with the Super Mario box and do it before.
# sentiment for text: 0.5994
# sentiment for emojis: 0
# sentiment combined: 0.5994
# ################################################
# The Barbie collection was the best!
# ################################################
# text found: The Barbie collection was the best!
# translated text: The Barbie collection was the best!
# sentiment for text: 0.6696
# sentiment for emojis: 0
# sentiment combined: 0.6696
# ################################################
# I need this tote in my life!!! too bad I'm poor :(
# ################################################
# text found: I need this tote in my life!!! too bad I'm poor :(
# translated text: I need this tote in my life!!! too bad I'm poor :(
# sentiment for text: -0.8854
# sentiment for emojis: 0
# sentiment combined: -0.8854
# ################################################
# Ok sarà anche bella ma l'anno prossimo non se la ricorderà più nessuno! Per quello che costerà non ne vale assolutamente la pena
# ################################################
# text found: Ok sarà anche bella ma l'anno prossimo non se la ricorderà più nessuno! Per quello che costerà non ne vale assolutamente la pena
# translated text: Ok will also be nice but next year will not remember anybody anymore! For what it will cost it is not worth it
# sentiment for text: 0.2006
# sentiment for emojis: 0
# sentiment combined: 0.2006
# ################################################
# Simona GnèGnè Miranda cioè ti rendi conto quanto é bella quella maglia??????
# ################################################
# text found: Simona GnèGnè Miranda cioè ti rendi conto quanto é bella quella maglia??????
# translated text: Simona GnèGnè Miranda ie you realize how good that mesh is ??????
# sentiment for text: 0.594
# sentiment for emojis: 0
# sentiment combined: 0.594
# ################################################
# Monica Morbiducci cosa potresti chiedere a fufo per Natale ...
# ################################################
# text found: Monica Morbiducci cosa potresti chiedere a fufo per Natale ...
# translated text: Monica Morbiducci what could you ask for fuck for Christmas ...
# sentiment for text: -0.5423
# sentiment for emojis: 0
# sentiment combined: -0.5423
# ################################################
# Ecco si Jeremy Scott dovrebbe trovarsi un lavoro serio e smetterla con queste cretinate
# ################################################
# text found: Ecco si Jeremy Scott dovrebbe trovarsi un lavoro serio e smetterla con queste cretinate
# translated text: Here's Jeremy Scott should be serious work and stop it with these cretinates
# sentiment for text: -0.3612
# sentiment for emojis: 0
# sentiment combined: -0.3612
# ################################################
# Nn si può guardare...
# ################################################
# text found: Nn si può guardare...
# translated text: Nn you can look ...
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# In mano ha un trapano???
# ################################################
# text found: In mano ha un trapano???
# translated text: In the hand has a drill ???
# sentiment for text: 0.5775
# sentiment for emojis: 0
# sentiment combined: 0.5775
# ################################################
# Ahahha! La puoi indossare quando vai allo studio😂
# ################################################
# emojis found: ['😂']
# text found: Ahahha! La puoi indossare quando vai allo studio
# translated text: Ahahha! You can wear it when you go to the studio
# sentiment for text: 0.0
# sentiment for emojis: 0.22096840377513338
# sentiment combined: 0.22096840377513338
# ################################################
# Quello zainetto?
# ################################################
# text found: Quello zainetto?
# translated text: That backpack?
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# No muoio !!!!! Serena !!! Aiuto
# ################################################
# text found: No muoio !!!!! Serena !!! Aiuto
# translated text: No die !!!!! Serena !!! Help
# sentiment for text: -0.6776
# sentiment for emojis: 0
# sentiment combined: -0.6776
# ################################################
# Shop vivi invidia 🔗📘
# ################################################
# emojis found: ['🔗', '📘']
# text found: Shop vivi invidia
# translated text: Shop alive envy
# sentiment for text: 0.128
# sentiment for emojis: 0
# sentiment combined: 0.128
# ################################################
# Shop vivi invidia 🔗📘
# ################################################
# emojis found: ['🔗', '📘']
# text found: Shop vivi invidia
# translated text: Shop alive envy
# sentiment for text: 0.128
# sentiment for emojis: 0
# sentiment combined: 0.128
# ################################################
# A jeremy non sai più che inventatte
# ################################################
# text found: A jeremy non sai più che inventatte
# translated text: Jeremy knows no more than invented
# sentiment for text: -0.296
# sentiment for emojis: 0
# sentiment combined: -0.296
# ################################################
# A jeremy non sai più che inventatte
# ################################################
# text found: A jeremy non sai più che inventatte
# translated text: Jeremy knows no more than invented
# sentiment for text: -0.296
# sentiment for emojis: 0
# sentiment combined: -0.296
# ################################################
# A jeremy non sai più che inventatte
# ################################################
# text found: A jeremy non sai più che inventatte
# translated text: Jeremy knows no more than invented
# sentiment for text: -0.296
# sentiment for emojis: 0
# sentiment combined: -0.296
# ################################################
# Sweet! :-D
# ################################################
# text found: Sweet! :-D
# translated text: Sweet! :-D
# sentiment for text: 0.8087
# sentiment for emojis: 0
# sentiment combined: 0.8087
# ################################################
# Questa collezione Non mi piace completamente !!!
# ################################################
# text found: Questa collezione Non mi piace completamente !!!
# translated text: This collection I do not like completely !!!
# sentiment for text: -0.4563
# sentiment for emojis: 0
# sentiment combined: -0.4563
# ################################################
# Anche no!
# ################################################
# text found: Anche no!
# translated text: Also not!
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# I'm in love 😍😍😘😘💜💜👾🎮✌🏻️
# ################################################
# emojis found: ['😍', '😍', '😘', '😘', '💜', '💜', '👾', '🎮', '✌', '🏻']
# text found: I'm in love ️
# translated text: I'm in love ️
# sentiment for text: 0.6369
# sentiment for emojis: 0
# sentiment combined: 0.6369
# ################################################
# Direi grazie a jeremy scott
# ################################################
# text found: Direi grazie a jeremy scott
# translated text: I would say thanks to jeremy scott
# sentiment for text: 0.4404
# sentiment for emojis: 0
# sentiment combined: 0.4404
# ################################################
# 😍😍😍
# ################################################
# emojis found: ['😍', '😍', '😍']
# text found:
# translated text:
# sentiment for text: 0.0
# sentiment for emojis: 0.8446034491796404
# sentiment combined: 0.8446034491796404
# ################################################
# Alfo te la regalo💞
# ################################################
# emojis found: ['💞']
# text found: Alfo te la regalo
# translated text: Alfo gave you the gift
# sentiment for text: 0.4404
# sentiment for emojis: 0.7423580786026202
# sentiment combined: 0.5913790393013101
# ################################################
# Va be questa è una bombazza
# ################################################
# text found: Va be questa è una bombazza
# translated text: This is a bomb
# sentiment for text: -0.4939
# sentiment for emojis: 0
# sentiment combined: -0.4939
# ################################################
# #mancoagratise
# ################################################
# text found: #mancoagratise
# translated text: #mancoagratise
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# #mancoagratise
# ################################################
# text found: #mancoagratise
# translated text: #mancoagratise
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Anastasia Nioré c'est pour toi ça !!!
# ################################################
# text found: Anastasia Nioré c'est pour toi ça !!!
# translated text: Anastasia Nioré is for you!
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Federica è finita
# ################################################
# text found: Federica è finita
# translated text: Federica is over
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Gioia Joy Ca den Pulli?
# ################################################
# text found: Gioia Joy Ca den Pulli?
# translated text: Joy Joy Ca den Pulli?
# sentiment for text: 0.8225
# sentiment for emojis: 0
# sentiment combined: 0.8225
# ################################################
# Naima 🔝🔝🔝
# ################################################
# emojis found: ['🔝', '🔝', '🔝']
# text found: Naima
# translated text: n Emma
# sentiment for text: 0.0
# sentiment for emojis: 0.6452145214521452
# sentiment combined: 0.6452145214521452
# ################################################
# Shit 😂😂😂😂 Lars Wiedemann
# ################################################
# emojis found: ['😂', '😂', '😂', '😂']
# text found: Shit  Lars Wiedemann
# translated text: Shit  Lars Wiedemann
# sentiment for text: -0.5574
# sentiment for emojis: 0.3459684037751334
# sentiment combined: -0.10571579811243331
# ################################################
# Shanti Om 😍😍😍😍😍
# ################################################
# emojis found: ['😍', '😍', '😍', '😍', '😍']
# text found: Shanti Om
# translated text: The peace
# sentiment for text: 0.5423
# sentiment for emojis: 0.7779367825129737
# sentiment combined: 0.6601183912564869
# ################################################
# Marco 😍
# ################################################
# emojis found: ['😍']
# text found: Marco
# translated text: Marco
# sentiment for text: 0.0
# sentiment for emojis: 0.6779367825129737
# sentiment combined: 0.6779367825129737
# ################################################
# Antonella GökceAntonio E Stefania Calabró😊
# ################################################
# emojis found: ['😊']
# text found: Antonella GökceAntonio E Stefania Calabró
# translated text: Antonella GökceAntonio E Stefania Calabró
# sentiment for text: 0.0
# sentiment for emojis: 0.6446955430006278
# sentiment combined: 0.6446955430006278
# ################################################
# Muryellen Keiko Kohatsu Maria Tereza Hulland
# ################################################
# text found: Muryellen Keiko Kohatsu Maria Tereza Hulland
# translated text: Muri ___ ___ ___ 0
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Jack Potkins 😍😍
# ################################################
# emojis found: ['😍', '😍']
# text found: Jack Potkins
# translated text: Jack Potkins
# sentiment for text: 0.0
# sentiment for emojis: 0.6779367825129737
# sentiment combined: 0.6779367825129737
# ################################################
# Eric Sewart xx
# ################################################
# text found: Eric Sewart xx
# translated text: Eric Sewart xx
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Rabia Aysel Gülec
# ################################################
# text found: Rabia Aysel Gülec
# translated text: Rabia Aysel Gülec
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Sophiie James
# ################################################
# text found: Sophiie James
# translated text: Sophiie James
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Stan🎮
# ################################################
# emojis found: ['🎮']
# text found: Stan
# translated text: Stan
# sentiment for text: 0.0
# sentiment for emojis: 0.441860465116279
# sentiment combined: 0.441860465116279
# ################################################
# Fabrizio Sorrentino
# ################################################
# text found: Fabrizio Sorrentino
# translated text: Fabrizio Sorrentino
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Bubb Adele Atiritikitomba
# ################################################
# text found: Bubb Adele Atiritikitomba
# translated text: Bubbs Adi Vichitikitoba
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Michael Lingscheidt
# ################################################
# text found: Michael Lingscheidt
# translated text: Michael Lingscheidt
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Marco Gambardella
# ################################################
# text found: Marco Gambardella
# translated text: Marco Gambardella
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Kris Ringler
# ################################################
# text found: Kris Ringler
# translated text: Kris Ringler
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Simona Ruocco
# ################################################
# text found: Simona Ruocco
# translated text: Simona Ruocco
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Chiara
# ################################################
# text found: Chiara
# translated text: Chiara
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Rachele Alunno
# ################################################
# text found: Rachele Alunno
# translated text: Rachele Alunno
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Jasmin Lücke
# ################################################
# text found: Jasmin Lücke
# translated text: Jasmine gap
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# {'text': 0.034524, 'emojis': 0.12038958424881001, 'combined': 0.1319979515999027}
# Connected to DB..
# Executin query:   CREATE TABLE IF NOT EXISTS `im_postsentiment` (
#   				`id` int(11) NOT NULL AUTO_INCREMENT,
#   				`idpost` int(11) DEFAULT NULL COMMENT 'post id',
#   				`text_sentiment` FLOAT(11,5),
#   				`emoji_sentiment` FLOAT(11,5),
#   				`combined_sentiment` FLOAT(11,5),
#   				PRIMARY KEY (`id`)
# 				) ENGINE=InnoDB AUTO_INCREMENT=0 DEFAULT CHARSET=utf8mb4;
# C:\Users\Pavle\Miniconda3\envs\thesis\lib\site-packages\pymysql\cursors.py:166: Warning: (1050, "Table 'im_postsentiment' already exists")
#   result = self._query(query)
# Executin query:   insert into im_postsentiment (idpost, text_sentiment, emoji_sentiment, combined_sentiment)
# 				values (79726, 0.034524, 0.12038958424881001, 0.1319979515999027);
# Closed DB connection..
# Connected to DB..
# Executin query:  select content from im_commento where idpost = 79727
# Closed DB connection..
# Visto giusto ieri sera
# Che peccato era veramente una grande artista....ma troppo fragile x sopportare popolarità e i media che gli stavano sempre addosso....
# ################################################
# text found: Visto giusto ieri sera
# Che peccato era veramente una grande artista....ma troppo fragile x sopportare popolarità e i media che gli stavano sempre addosso....
# translated text: Well seen last night
# What a pity was really a great artist .... but too fragile x endure popularity and media that were always on him ....
# sentiment for text: 0.778
# sentiment for emojis: 0
# sentiment combined: 0.778
# ################################################
# I lik Amy winehouse song she is best 😃😀😊😊
# ################################################
# emojis found: ['😃', '😀', '😊', '😊']
# text found: I lik Amy winehouse song she is best
# translated text: I lik Amy winehouse song she is best
# sentiment for text: 0.6369
# sentiment for emojis: 0.6047970475196099
# sentiment combined: 0.6208485237598049
# ################################################
# Visto al cinema e comprato ieri il dvd! ❤
# ################################################
# emojis found: ['❤']
# text found: Visto al cinema e comprato ieri il dvd!
# translated text: Seen at the movies and bought the dvd yesterday!
# sentiment for text: 0.0
# sentiment for emojis: 0.7460869565217392
# sentiment combined: 0.7460869565217392
# ################################################
# Love Amy Winehouse forever
# ################################################
# text found: Love Amy Winehouse forever
# translated text: Love Amy Winehouse forever
# sentiment for text: 0.6369
# sentiment for emojis: 0
# sentiment combined: 0.6369
# ################################################
# ❤️la piu grande di tutti i tempi😔😘😍
# ################################################
# emojis found: ['❤', '😔', '😘', '😍']
# text found: ️la piu grande di tutti i tempi
# translated text: ️ the greatest of all time
# sentiment for text: 0.6369
# sentiment for emojis: 0.49493000842832957
# sentiment combined: 0.5659150042141647
# ################################################
# Gian MA COSA FAIII
# ################################################
# text found: Gian MA COSA FAIII
# translated text: Gian MA COSA FAITH
# sentiment for text: 0.5473
# sentiment for emojis: 0
# sentiment combined: 0.5473
# ################################################
# Great musician. Love her style. Miss her
# ################################################
# text found: Great musician. Love her style. Miss her
# translated text: Great musician. Love her style. Miss her
# sentiment for text: 0.8271
# sentiment for emojis: 0
# sentiment combined: 0.8271
# ################################################
# ❤️
# ################################################
# emojis found: ['❤']
# text found: ️
# translated text: ️
# sentiment for text: 0.0
# sentiment for emojis: 0.7460869565217392
# sentiment combined: 0.7460869565217392
# ################################################
# ❤️
# ################################################
# emojis found: ['❤']
# text found: ️
# translated text: ️
# sentiment for text: 0.0
# sentiment for emojis: 0.7460869565217392
# sentiment combined: 0.7460869565217392
# ################################################
# ❤️
# ################################################
# emojis found: ['❤']
# text found: ️
# translated text: ️
# sentiment for text: 0.0
# sentiment for emojis: 0.7460869565217392
# sentiment combined: 0.7460869565217392
# ################################################
# Sally Luigina Chemist
# ################################################
# text found: Sally Luigina Chemist
# translated text: Sally Luigina Chemist
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# 李浚瑋
# ################################################
# text found: 李浚瑋
# translated text: Li Junwei
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# {'text': 0.3385916666666666, 'emojis': 0.340339573502908, 'combined': 0.5800342795050771}
# Connected to DB..
# Executin query:   CREATE TABLE IF NOT EXISTS `im_postsentiment` (
#   				`id` int(11) NOT NULL AUTO_INCREMENT,
#   				`idpost` int(11) DEFAULT NULL COMMENT 'post id',
#   				`text_sentiment` FLOAT(11,5),
#   				`emoji_sentiment` FLOAT(11,5),
#   				`combined_sentiment` FLOAT(11,5),
#   				PRIMARY KEY (`id`)
# 				) ENGINE=InnoDB AUTO_INCREMENT=0 DEFAULT CHARSET=utf8mb4;
# Executin query:   insert into im_postsentiment (idpost, text_sentiment, emoji_sentiment, combined_sentiment)
# 				values (79727, 0.3385916666666666, 0.340339573502908, 0.5800342795050771);
# Closed DB connection..
# Connected to DB..
# Executin query:  select content from im_commento where idpost = 79728
# Closed DB connection..
# Se ci fosse un termometro per misurare la tristezza di questi due modelli (la metto al maschile perché quello/a a sinistra non sono riuscita a definirlo/a) penso che il mercurio romperebbe il vetro 😂😂
# ################################################
# emojis found: ['😂', '😂']
# text found: Se ci fosse un termometro per misurare la tristezza di questi due modelli (la metto al maschile perché quello/a a sinistra non sono riuscita a definirlo/a) penso che il mercurio romperebbe il vetro
# translated text: If there was a thermometer to measure the sadness of these two models (I put it on the male because left / right I could not define it) I think mercury breaks the glass
# sentiment for text: -0.4404
# sentiment for emojis: 0.22096840377513338
# sentiment combined: -0.10971579811243332
# ################################################
# "Evvai"..modelli sempre più magri e sempre più asessuati!!!!!
# Ma che orrore!
# ################################################
# text found: "Evvai"..modelli sempre più magri e sempre più asessuati!!!!!
# Ma che orrore!
# translated text: "Evvai" .. more and more thin models and more and more asexual !!!!!
# But what a horror!
# sentiment for text: -0.7067
# sentiment for emojis: 0
# sentiment combined: -0.7067
# ################################################
# Givenchy Collection King 👌 dsquared top👌👌
# ################################################
# emojis found: ['👌', '👌', '👌']
# text found: Givenchy Collection King  dsquared top
# translated text: Givenchy Collection King  dsquared top
# sentiment for text: 0.2023
# sentiment for emojis: 0.7304273504273504
# sentiment combined: 0.4663636752136752
# ################################################
# Is this a man or a girl on the left?
# ################################################
# text found: Is this a man or a girl on the left?
# translated text: Is this a man or a girl on the left?
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Per quanto riguarda i modelli non è certo colpa del negozio ma della tendenza generale
# in sfilata si vedono cose assurde
# ################################################
# text found: Per quanto riguarda i modelli non è certo colpa del negozio ma della tendenza generale
# in sfilata si vedono cose assurde
# translated text: As far as models are concerned, it is not the fault of the store but of the general trend
# in the parade you see absurd things
# sentiment for text: 0.1603
# sentiment for emojis: 0
# sentiment combined: 0.1603
# ################################################
# Nope
# ################################################
# text found: Nope
# translated text: Nope
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Ma é appena finita dai!!! Esagerati .....
# ################################################
# text found: Ma é appena finita dai!!! Esagerati .....
# translated text: But it's just over !!! Exaggerated .....
# sentiment for text: -0.3129
# sentiment for emojis: 0
# sentiment combined: -0.3129
# ################################################
# Che schifo
# ################################################
# text found: Che schifo
# translated text: What a disgust
# sentiment for text: -0.5994
# sentiment for emojis: 0
# sentiment combined: -0.5994
# ################################################
# Ma...quei due tossici di metanfetamina nella foto chi sono...?
# ################################################
# text found: Ma...quei due tossici di metanfetamina nella foto chi sono...?
# translated text: But ... those two methamphetamine poisonants in the picture who I am ...?
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# sisi diffic sporcar , vosevo dervila così in questa Modo,,,
# Virgoline virgoline cccccc
# ################################################
# text found: sisi diffic sporcar  vosevo dervila così in questa Modo
# Virgoline virgoline cccccc
# translated text: I could hardly dive so in this way
# Virgoline virgoline cccccc
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Ma chi è l'uomo e chi la donna? #aborro
# ################################################
# text found: Ma chi è l'uomo e chi la donna? #aborro
# translated text: But who is the man and who the woman? #aborro
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# Che fame hanno?
# ################################################
# text found: Che fame hanno?
# translated text: What hunger do they have?
# sentiment for text: -0.25
# sentiment for emojis: 0
# sentiment combined: -0.25
# ################################################
# Bruto !!
# ################################################
# text found: Bruto !!
# translated text: Stupid !!
# sentiment for text: -0.6103
# sentiment for emojis: 0
# sentiment combined: -0.6103
# ################################################
# Ottimo assortimento di pre fall Un negozio on line fantastico
# ################################################
# text found: Ottimo assortimento di pre fall Un negozio on line fantastico
# translated text: Great Pre Fall Set A fantastic online store
# sentiment for text: 0.8271
# sentiment for emojis: 0
# sentiment combined: 0.8271
# ################################################
# Splendida
# ################################################
# text found: Splendida
# translated text: Beautiful
# sentiment for text: 0.5994
# sentiment for emojis: 0
# sentiment combined: 0.5994
# ################################################
# musim dingin aja bru mulai
# ################################################
# text found: musim dingin aja bru mulai
# translated text: winter aja bru start
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# 😍👏🏽
# ################################################
# emojis found: ['😍', '👏', '🏽']
# text found:
# translated text:
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# <3
# ################################################
# text found: <3
# translated text: <3
# sentiment for text: 0.4404
# sentiment for emojis: 0
# sentiment combined: 0.4404
# ################################################
# <3
# ################################################
# text found: <3
# translated text: <3
# sentiment for text: 0.4404
# sentiment for emojis: 0
# sentiment combined: 0.4404
# ################################################
# Elena Elisabetta Valentini
# ################################################
# text found: Elena Elisabetta Valentini
# translated text: Elena Elisabetta Valentini
# sentiment for text: 0.0
# sentiment for emojis: 0
# sentiment combined: 0.0
# ################################################
# {'text': -0.012490000000000012, 'emojis': 0.04756978771012419, 'combined': 0.017247393855062083}
# Connected to DB..
# Executin query:   CREATE TABLE IF NOT EXISTS `im_postsentiment` (
#   				`id` int(11) NOT NULL AUTO_INCREMENT,
#   				`idpost` int(11) DEFAULT NULL COMMENT 'post id',
#   				`text_sentiment` FLOAT(11,5),
#   				`emoji_sentiment` FLOAT(11,5),
#   				`combined_sentiment` FLOAT(11,5),
#   				PRIMARY KEY (`id`)
# 				) ENGINE=InnoDB AUTO_INCREMENT=0 DEFAULT CHARSET=utf8mb4;
# Executin query:   insert into im_postsentiment (idpost, text_sentiment, emoji_sentiment, combined_sentiment)
# 				values (79728, -0.012490000000000012, 0.04756978771012419, 0.017247393855062083);
# Closed DB connection..
# Connected to DB..
# Executin query:  select content from im_commento where idpost = 79729
# Closed DB connection..
# Hmmmm.... ;) :)
# ################################################
# text found: Hmmmm.... ;) :)
# translated text: Hmmmm.... ;) :)
# sentiment for text: 0.5994
# sentiment for emojis: 0
# sentiment combined: 0.5994
# ################################################
# Hmmmm.... ;) :)
# ################################################
# text found: Hmmmm.... ;) :)
# translated text: Hmmmm.... ;) :)
# sentiment for text: 0.5994
# sentiment for emojis: 0
# sentiment combined: 0.5994
# ################################################
# Alireza Rezaeii
# ################################################
# text found: Alireza Rezaeii
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-e8e8b34618a4> in <module>()
#      14 for r in results[:10]:
#      15         listOfCom = db.getAllCommentsForPost(r[0])
# ---> 16         sent = s.calcSummedSentiment(listOfCom)
#      17         db.insertSentForPost(r[0], sent)
#
# D:\Politecnico di Milano\Semester 4\Thesis polimi\SentimentAnalysis\SentimentCalculator.py in calcSummedSentiment(self, listOfComments)
#     141                                 continue
#     142
# --> 143                         sentScore = self.__calcSentiment(comment)
#     144                         summedSent['text'] += sentScore['text']['compound']
#     145                         summedSent['emojis'] += sentScore['emojis']
#
# D:\Politecnico di Milano\Semester 4\Thesis polimi\SentimentAnalysis\SentimentCalculator.py in __calcSentiment(self, text)
#     114                 print('text found: %s' %postContent['text'])
#     115
# --> 116                 postContent['text'] = self.__translate(postContent['text'])
#     117
#     118                 print('translated text: %s' %postContent['text'])
#
# D:\Politecnico di Milano\Semester 4\Thesis polimi\SentimentAnalysis\SentimentCalculator.py in __translate(self, text, targetLng)
#      16         def __translate(self, text, targetLng = 'en'):
#      17                 gt = Translator()
# ---> 18                 translation = gt.translate(text, dest = targetLng)
#      19
#      20                 return translation.text
#
# ~\Miniconda3\envs\thesis\lib\site-packages\googletrans\client.py in translate(self, text, dest, src)
#     130
#     131         origin = text
# --> 132         data = self._translate(text, dest, src)
#     133
#     134         # this code will be updated when the format is changed.
#
# ~\Miniconda3\envs\thesis\lib\site-packages\googletrans\client.py in _translate(self, text, dest, src)
#      55             text = text.decode('utf-8')
#      56
# ---> 57         token = self.token_acquirer.do(text)
#      58         params = utils.build_params(query=text, src=src, dest=dest,
#      59                                     token=token)
#
# ~\Miniconda3\envs\thesis\lib\site-packages\googletrans\gtoken.py in do(self, text)
#     178
#     179     def do(self, text):
# --> 180         self._update()
#     181         tk = self.acquire(text)
#     182         return tk
#
# ~\Miniconda3\envs\thesis\lib\site-packages\googletrans\gtoken.py in _update(self)
#      55             return
#      56
# ---> 57         r = self.session.get(self.host)
#      58         # this will be the same as python code after stripping out a reserved word 'var'
#      59         code = unicode(self.RE_TKK.search(r.text).group(1)).replace('var ', '')
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\sessions.py in get(self, url, **kwargs)
#     529
#     530         kwargs.setdefault('allow_redirects', True)
# --> 531         return self.request('GET', url, **kwargs)
#     532
#     533     def options(self, url, **kwargs):
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         # Trigger any extra validation we need to do.
#     344         try:
# --> 345             self._validate_conn(conn)
#     346         except (SocketTimeout, BaseSSLError) as e:
#     347             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     842         # Force connect early to allow us to validate the connection.
#     843         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 844             conn.connect()
#     845
#     846         if not conn.is_verified:
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# ~\Miniconda3\envs\thesis\lib\site-packages\requests\packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     323         context.load_cert_chain(certfile, keyfile)
#     324     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 325         return context.wrap_socket(sock, server_hostname=server_hostname)
#     326
#     327     warnings.warn(
#
# ~\Miniconda3\envs\thesis\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     399                          suppress_ragged_eofs=suppress_ragged_eofs,
#     400                          server_hostname=server_hostname,
# --> 401                          _context=self, _session=session)
#     402
#     403     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# ~\Miniconda3\envs\thesis\lib\ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     806                         # non-blocking
#     807                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 808                     self.do_handshake()
#     809
#     810             except (OSError, ValueError):
#
# ~\Miniconda3\envs\thesis\lib\ssl.py in do_handshake(self, block)
#    1059             if timeout == 0.0 and block:
#    1060                 self.settimeout(None)
# -> 1061             self._sslobj.do_handshake()
#    1062         finally:
#    1063             self.settimeout(timeout)
#
# ~\Miniconda3\envs\thesis\lib\ssl.py in do_handshake(self)
#     681     def do_handshake(self):
#     682         """Start the SSL/TLS handshake."""
# --> 683         self._sslobj.do_handshake()
#     684         if self.context.check_hostname:
#     685             if not self.server_hostname:
#
# KeyboardInterrupt:
